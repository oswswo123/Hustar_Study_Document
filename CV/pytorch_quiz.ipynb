# %% [markdown]
# ### Pytorch Quiz
# - CNN을 활용한 모델을 만들어서 정확도 95% 이상의 Classifier를 만드세요
# - 코드 수정 가능

# %%
from matplotlib import pyplot as plt
import torch
from torchvision import datasets
from torchvision.transforms import ToTensor
import torch.nn as nn
from torch import optim
from torch.utils.data import DataLoader

# %% [markdown]
# #### Dataset download

# %%
train_data = datasets.MNIST(
    root = 'data',
    train = True,                         
    transform = ToTensor(), 
    download = True,            
)
dataloader_train = DataLoader(train_data, 
                              batch_size=16, 
                              shuffle=True)

test_data = datasets.MNIST(
    root = 'data', 
    train = False, 
    transform = ToTensor()
)
dataloader_test = DataLoader(test_data, 
                              batch_size=16, 
                              shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 0it [00:00, ?it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 0it [00:00, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 0it [00:00, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 0it [00:00, ?it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# Processing...
# Done!

# %% [markdown]
# #### Check images

# %%
figure = plt.figure(figsize=(10, 8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(train_data), size=(1,)).item()
    img, label = train_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(label)
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %% [markdown]
# #### CNN
# ##### structure
# - Convolution 1 : channels 16, kernel size 5, stride 1, padding 2 (output resolution?)
# - ReLU
# - MaxPool : kernel_size 2, stride 2
# - Convlution 2 : channels 32, kernel size 5, stride 1, padding 2 (output resolution?)
# - Linear : output channels 10
#
# ##### https://pytorch.org/docs/1.12/nn.html

# %%
class CNN(nn.Module):
    def __init__(self):
        ## TODO ##
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=1,
                               out_channels=16,
                               kernel_size=(5, 5),
                               stride=1,
                               padding=2)
        self.conv2 = nn.Conv2d(in_channels=16,
                               out_channels=32,
                               kernel_size=(5, 5),
                               stride=1,
                               padding=2)
        self.maxpool = nn.MaxPool2d(kernel_size=(2, 2), 
                                    stride=2)
        self.fc1 = nn.Linear(in_features=6272,
                             out_features=10)
        
    def forward(self, x):
        ## TODO ##
        x = self.conv1(x)
        x = nn.ReLU()(x)
        x = self.maxpool(x)
        x = self.conv2(x)
        # x = x.view(x.shape[0], -1)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        
        return x

# %% [markdown]
# #### Train

# %%
cnn = CNN()
loss_func = nn.CrossEntropyLoss()   
optimizer = optim.Adam(cnn.parameters(), lr = 0.01)

# %%
# Train the model
num_epochs = 5

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(dataloader_train):
        output = cnn(images)
        loss = loss_func(output, labels)

        # clear gradients for this training step   
        optimizer.zero_grad()           

        # backpropagation, compute gradients 
        loss.backward()    
        # apply gradients             
        optimizer.step()                

        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}], Loss: {:.4f}' 
                   .format(epoch + 1, num_epochs, i + 1, loss.item()))
# Out:
# Epoch [1/5], Step [100], Loss: 0.1780
# Epoch [1/5], Step [200], Loss: 0.1051
# Epoch [1/5], Step [300], Loss: 0.1154
# Epoch [1/5], Step [400], Loss: 0.4467
# Epoch [1/5], Step [500], Loss: 0.7361
# Epoch [1/5], Step [600], Loss: 0.3147
# Epoch [1/5], Step [700], Loss: 0.0437
# Epoch [1/5], Step [800], Loss: 0.1704
# Epoch [1/5], Step [900], Loss: 0.3990
# Epoch [1/5], Step [1000], Loss: 0.6619
# Epoch [1/5], Step [1100], Loss: 0.1183
# Epoch [1/5], Step [1200], Loss: 0.0907
# Epoch [1/5], Step [1300], Loss: 0.0114
# Epoch [1/5], Step [1400], Loss: 0.0369
# Epoch [1/5], Step [1500], Loss: 0.5862
# Epoch [1/5], Step [1600], Loss: 0.0557
# Epoch [1/5], Step [1700], Loss: 0.9294
# Epoch [1/5], Step [1800], Loss: 0.4686
# Epoch [1/5], Step [1900], Loss: 0.2636
# Epoch [1/5], Step [2000], Loss: 0.6491
# Epoch [1/5], Step [2100], Loss: 0.5055
# Epoch [1/5], Step [2200], Loss: 0.3384
# Epoch [1/5], Step [2300], Loss: 0.5880
# Epoch [1/5], Step [2400], Loss: 0.2073
# Epoch [1/5], Step [2500], Loss: 0.2121
# Epoch [1/5], Step [2600], Loss: 0.0647
# Epoch [1/5], Step [2700], Loss: 0.9758
# Epoch [1/5], Step [2800], Loss: 0.2500
# Epoch [1/5], Step [2900], Loss: 0.2728
# Epoch [1/5], Step [3000], Loss: 0.0223
# Epoch [1/5], Step [3100], Loss: 0.1104
# Epoch [1/5], Step [3200], Loss: 0.0883
# Epoch [1/5], Step [3300], Loss: 0.0474
# Epoch [1/5], Step [3400], Loss: 0.0494
# Epoch [1/5], Step [3500], Loss: 0.3667
# Epoch [1/5], Step [3600], Loss: 0.7746
# Epoch [1/5], Step [3700], Loss: 0.4203
# Epoch [2/5], Step [100], Loss: 0.1250
# Epoch [2/5], Step [200], Loss: 0.2564
# Epoch [2/5], Step [300], Loss: 0.1210
# Epoch [2/5], Step [400], Loss: 1.0619
# Epoch [2/5], Step [500], Loss: 0.4648
# Epoch [2/5], Step [600], Loss: 0.0611
# Epoch [2/5], Step [700], Loss: 0.6607
# Epoch [2/5], Step [800], Loss: 0.4251
# Epoch [2/5], Step [900], Loss: 0.2326
# Epoch [2/5], Step [1000], Loss: 0.8625
# Epoch [2/5], Step [1100], Loss: 0.7451
# Epoch [2/5], Step [1200], Loss: 0.5053
# Epoch [2/5], Step [1300], Loss: 0.0987
# Epoch [2/5], Step [1400], Loss: 0.2201
# Epoch [2/5], Step [1500], Loss: 0.2472
# Epoch [2/5], Step [1600], Loss: 0.2143
# Epoch [2/5], Step [1700], Loss: 0.3977
# Epoch [2/5], Step [1800], Loss: 0.4155
# Epoch [2/5], Step [1900], Loss: 0.1935
# Epoch [2/5], Step [2000], Loss: 0.0090
# Epoch [2/5], Step [2100], Loss: 0.4552
# Epoch [2/5], Step [2200], Loss: 0.2203
# Epoch [2/5], Step [2300], Loss: 0.3827
# Epoch [2/5], Step [2400], Loss: 0.0846
# Epoch [2/5], Step [2500], Loss: 0.0263
# Epoch [2/5], Step [2600], Loss: 0.2145
# Epoch [2/5], Step [2700], Loss: 0.1106
# Epoch [2/5], Step [2800], Loss: 1.1342
# Epoch [2/5], Step [2900], Loss: 0.1244
# Epoch [2/5], Step [3000], Loss: 0.0579
# Epoch [2/5], Step [3100], Loss: 0.0305
# Epoch [2/5], Step [3200], Loss: 0.3621
# Epoch [2/5], Step [3300], Loss: 0.3888
# Epoch [2/5], Step [3400], Loss: 0.9507
# Epoch [2/5], Step [3500], Loss: 1.1144
# Epoch [2/5], Step [3600], Loss: 0.0325
# Epoch [2/5], Step [3700], Loss: 0.0333
# Epoch [3/5], Step [100], Loss: 0.0173
# Epoch [3/5], Step [200], Loss: 0.0356
# Epoch [3/5], Step [300], Loss: 0.2131
# Epoch [3/5], Step [400], Loss: 0.5691
# Epoch [3/5], Step [500], Loss: 1.1786
# Epoch [3/5], Step [600], Loss: 0.1009
# Epoch [3/5], Step [700], Loss: 0.1564
# Epoch [3/5], Step [800], Loss: 0.0078
# Epoch [3/5], Step [900], Loss: 0.9369
# Epoch [3/5], Step [1000], Loss: 0.0627
# Epoch [3/5], Step [1100], Loss: 0.3787
# Epoch [3/5], Step [1200], Loss: 0.0666
# Epoch [3/5], Step [1300], Loss: 0.0923
# Epoch [3/5], Step [1400], Loss: 0.1230
# Epoch [3/5], Step [1500], Loss: 0.5259
# Epoch [3/5], Step [1600], Loss: 0.7029
# Epoch [3/5], Step [1700], Loss: 0.1101
# Epoch [3/5], Step [1800], Loss: 0.7784
# Epoch [3/5], Step [1900], Loss: 0.2575
# Epoch [3/5], Step [2000], Loss: 0.3101
# Epoch [3/5], Step [2100], Loss: 0.9964
# Epoch [3/5], Step [2200], Loss: 0.0061
# Epoch [3/5], Step [2300], Loss: 0.0095
# Epoch [3/5], Step [2400], Loss: 0.4406
# Epoch [3/5], Step [2500], Loss: 0.9092
# Epoch [3/5], Step [2600], Loss: 0.1746
# Epoch [3/5], Step [2700], Loss: 0.8172
# Epoch [3/5], Step [2800], Loss: 0.2353
# Epoch [3/5], Step [2900], Loss: 0.8785
# Epoch [3/5], Step [3000], Loss: 0.0475
# Epoch [3/5], Step [3100], Loss: 1.2975
# Epoch [3/5], Step [3200], Loss: 0.0450
# Epoch [3/5], Step [3300], Loss: 0.0078
# Epoch [3/5], Step [3400], Loss: 0.6243
# Epoch [3/5], Step [3500], Loss: 0.0105
# Epoch [3/5], Step [3600], Loss: 0.0779
# Epoch [3/5], Step [3700], Loss: 0.0016
# Epoch [4/5], Step [100], Loss: 0.3446
# Epoch [4/5], Step [200], Loss: 0.5678
# Epoch [4/5], Step [300], Loss: 0.0071
# Epoch [4/5], Step [400], Loss: 0.2029
# Epoch [4/5], Step [500], Loss: 0.1946
# Epoch [4/5], Step [600], Loss: 0.3937
# Epoch [4/5], Step [700], Loss: 0.0012
# Epoch [4/5], Step [800], Loss: 0.0594
# Epoch [4/5], Step [900], Loss: 0.3022
# Epoch [4/5], Step [1000], Loss: 0.3480
# Epoch [4/5], Step [1100], Loss: 0.8578
# Epoch [4/5], Step [1200], Loss: 0.5594
# Epoch [4/5], Step [1300], Loss: 0.0011
# Epoch [4/5], Step [1400], Loss: 0.1417
# Epoch [4/5], Step [1500], Loss: 0.1638
# Epoch [4/5], Step [1600], Loss: 0.1553
# Epoch [4/5], Step [1700], Loss: 0.0653
# Epoch [4/5], Step [1800], Loss: 0.6513
# Epoch [4/5], Step [1900], Loss: 0.0736
# Epoch [4/5], Step [2000], Loss: 0.0451
# Epoch [4/5], Step [2100], Loss: 0.7642
# Epoch [4/5], Step [2200], Loss: 0.1749
# Epoch [4/5], Step [2300], Loss: 0.0000
# Epoch [4/5], Step [2400], Loss: 0.2782
# Epoch [4/5], Step [2500], Loss: 0.2663
# Epoch [4/5], Step [2600], Loss: 1.2263
# Epoch [4/5], Step [2700], Loss: 0.2908
# Epoch [4/5], Step [2800], Loss: 0.2173
# Epoch [4/5], Step [2900], Loss: 0.6669
# Epoch [4/5], Step [3000], Loss: 0.7791
# Epoch [4/5], Step [3100], Loss: 0.0193
# Epoch [4/5], Step [3200], Loss: 0.0026
# Epoch [4/5], Step [3300], Loss: 0.7858
# Epoch [4/5], Step [3400], Loss: 0.4749
# Epoch [4/5], Step [3500], Loss: 0.0029
# Epoch [4/5], Step [3600], Loss: 0.8827
# Epoch [4/5], Step [3700], Loss: 0.9418
# Epoch [5/5], Step [100], Loss: 0.1615
# Epoch [5/5], Step [200], Loss: 0.3405
# Epoch [5/5], Step [300], Loss: 0.0048
# Epoch [5/5], Step [400], Loss: 0.2569
# Epoch [5/5], Step [500], Loss: 0.0032
# Epoch [5/5], Step [600], Loss: 0.2184
# Epoch [5/5], Step [700], Loss: 0.4457
# Epoch [5/5], Step [800], Loss: 0.0182
# Epoch [5/5], Step [900], Loss: 0.0061
# Epoch [5/5], Step [1000], Loss: 0.3713
# Epoch [5/5], Step [1100], Loss: 0.2723
# Epoch [5/5], Step [1200], Loss: 0.1710
# Epoch [5/5], Step [1300], Loss: 0.4733
# Epoch [5/5], Step [1400], Loss: 1.0450
# Epoch [5/5], Step [1500], Loss: 0.3132
# Epoch [5/5], Step [1600], Loss: 0.0063
# Epoch [5/5], Step [1700], Loss: 0.4241
# Epoch [5/5], Step [1800], Loss: 0.3482
# Epoch [5/5], Step [1900], Loss: 0.2438
# Epoch [5/5], Step [2000], Loss: 0.0609
# Epoch [5/5], Step [2100], Loss: 0.0253
# Epoch [5/5], Step [2200], Loss: 0.0590
# Epoch [5/5], Step [2300], Loss: 0.1599
# Epoch [5/5], Step [2400], Loss: 0.0578
# Epoch [5/5], Step [2500], Loss: 0.7573
# Epoch [5/5], Step [2600], Loss: 0.0643
# Epoch [5/5], Step [2700], Loss: 0.0664
# Epoch [5/5], Step [2800], Loss: 0.9299
# Epoch [5/5], Step [2900], Loss: 0.8438
# Epoch [5/5], Step [3000], Loss: 0.7938
# Epoch [5/5], Step [3100], Loss: 0.1395
# Epoch [5/5], Step [3200], Loss: 0.2132
# Epoch [5/5], Step [3300], Loss: 0.2244
# Epoch [5/5], Step [3400], Loss: 0.1736
# Epoch [5/5], Step [3500], Loss: 0.4725
# Epoch [5/5], Step [3600], Loss: 0.2828
# Epoch [5/5], Step [3700], Loss: 0.2073

# %% [markdown]
# #### Test

# %%
cnn.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in dataloader_test:
        test_output = cnn(images) #, last_layer
        pred_y = torch.max(test_output, 1)[1].data.squeeze()
        correct += (pred_y == labels).sum().item()
        total += labels.size(0)
    accuracy = correct / total * 100
    
print('Test Accuracy of the model on the 10000 test images: %.2f Percent' % accuracy)
# Out:
# Test Accuracy of the model on the 10000 test images: 90.03 Percent
